# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds = pd.read_csv("Churn_Modelling.csv")
ds
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
ds.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df = ds[ds.columns[3:14]]
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
df["Gender"] = pd.get_dummies(df["Gender"],drop_first=True)
df
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France       0   42       2       0.00              1
# 1             608     Spain       0   41       1   83807.86              1
# 2             502    France       0   42       8  159660.80              3
# 3             699    France       0   39       1       0.00              2
# 4             850     Spain       0   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# ...

# %%
df[["Germany","Spain"]]=pd.get_dummies(df["Geography"],drop_first=True)
df
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France       0   42       2       0.00              1
# 1             608     Spain       0   41       1   83807.86              1
# 2             502    France       0   42       8  159660.80              3
# 3             699    France       0   39       1       0.00              2
# 4             850     Spain       0   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# ...

# %%
df.drop("Geography",axis=1,inplace=True)
df
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619       0   42       2       0.00              1          1
# 1             608       0   41       1   83807.86              1          0
# 2             502       0   42       8  159660.80              3          1
# 3             699       0   39       1       0.00              2          0
# 4             850       0   43       2  125510.82              1          1
# ...           ...     ...  ...     ...        ...            ...        ...
# 9995          771       1   39       5       0.00              2          1
# ...

# %%
df.columns
# Out:
# Index(['CreditScore', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts',
#        'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited', 'Germany',
#        'Spain'],
#       dtype='object')

# %%
X =df[['CreditScore', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts',
       'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Germany',
       'Spain']].values

# %%
X
# Out:
# array([[6.1900000e+02, 0.0000000e+00, 4.2000000e+01, ..., 1.0134888e+05,
#         0.0000000e+00, 0.0000000e+00],
#        [6.0800000e+02, 0.0000000e+00, 4.1000000e+01, ..., 1.1254258e+05,
#         0.0000000e+00, 1.0000000e+00],
#        [5.0200000e+02, 0.0000000e+00, 4.2000000e+01, ..., 1.1393157e+05,
#         0.0000000e+00, 0.0000000e+00],
#        ...,
#        [7.0900000e+02, 0.0000000e+00, 3.6000000e+01, ..., 4.2085580e+04,
#         0.0000000e+00, 0.0000000e+00],
#        [7.7200000e+02, 1.0000000e+00, 4.2000000e+01, ..., 9.2888520e+04,
#         1.0000000e+00, 0.0000000e+00],
#        [7.9200000e+02, 0.0000000e+00, 2.8000000e+01, ..., 3.8190780e+04,
#         0.0000000e+00, 0.0000000e+00]])

# %%
Y = df["Exited"].values
Y
# Out:
# array([1, 0, 1, ..., 1, 1, 0])

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import r2_score

# %%
from sklearn.preprocessing import StandardScaler
stscaler = StandardScaler()
X = stscaler.fit_transform(X)

# %%
X
# Out:
# array([[-0.32622142, -1.09598752,  0.29351742, ...,  0.02188649,
#         -0.57873591, -0.57380915],
#        [-0.44003595, -1.09598752,  0.19816383, ...,  0.21653375,
#         -0.57873591,  1.74273971],
#        [-1.53679418, -1.09598752,  0.29351742, ...,  0.2406869 ,
#         -0.57873591, -0.57380915],
#        ...,
#        [ 0.60498839, -1.09598752, -0.27860412, ..., -1.00864308,
#         -0.57873591, -0.57380915],
#        [ 1.25683526,  0.91241915,  0.29351742, ..., -0.12523071,
#          1.72790383, -0.57380915],
#        [ 1.46377078, -1.09598752, -1.04143285, ..., -1.07636976,
#         -0.57873591, -0.57380915]])

# %%
# Divide dataset  into training and test
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size =0.2 , random_state=0)

# %%
regressor = RandomForestClassifier(n_estimators=200,criterion="entropy",random_state=0)
regressor.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
regressor.score(X_test,Y_test)
# Out:
# 0.8705

# %%
regressor.predict(X)
# Out:
# array([0.75666667, 0.16      , 0.98      , ..., 0.68666667, 0.67666667,
#        0.02      ])

# %%
Y_test
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
regressor.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# # DB SCAN

# %%
from sklearn.cluster import DBSCAN

# %%
data =X

# %%
from sklearn.preprocessing import StandardScaler
stscaler = StandardScaler()
data = stscaler.fit_transform(data)

# %%
dbsc = DBSCAN(eps = 0.6, min_samples=20).fit(data)
dbsc.labels_
# Out:
# array([-1, -1, -1, ..., -1, -1, -1])

# %%
labels = dbsc.labels_
core_samples = np.zeros_like(labels,dtype=bool)
core_samples[dbsc.core_sample_indices_]=True

# %%
labels
# Out:
# array([-1, -1, -1, ..., -1, -1, -1])

# %%
data

# %% [markdown]
# # Hierarchial

# %%
from sklearn import preprocessing
data = preprocessing.normalize(X)
# using dendrogram to find the optimal number of clusters
import scipy.cluster.hierarchy as sch
dendrogram=sch.dendrogram(sch.linkage(data,method='ward'))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distance')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
hc=AgglomerativeClustering(n_clusters= 2, affinity= 'euclidean', linkage= 'ward')
y_hc=hc.fit_predict(X)
y_hc
# Out:
# array([1, 0, 0, ..., 1, 0, 0])

# %%
Y
# Out:
# array([1, 0, 1, ..., 1, 1, 0])

# %% [markdown]
# # Artificial Neural Network (ANN)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier = Sequential()

# %%
classifier.add(Dense(output_dim=6,init = "uniform", activation="relu",input_dim=11))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=11, units=6, kernel_initializer="uniform")`
#   """Entry point for launching an IPython kernel.

# %%
classifier.add(Dense(output_dim=6,init="uniform",activation="relu"))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=2, kernel_initializer="uniform")`
#   """Entry point for launching an IPython kernel.

# %%
classifier.add(Dense(output_dim=1,init="uniform",activation="sigmoid"))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1, kernel_initializer="uniform")`
#   """Entry point for launching an IPython kernel.

# %%
classifier.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
classifier.fit(X_train,Y_train,batch_size=1000,nb_epoch=50)
# Out:
# Epoch 1/50
# 8000/8000 [==============================] - 0s 3us/step - loss: 0.3320 - accuracy: 0.8644
# Epoch 2/50
# 8000/8000 [==============================] - 0s 4us/step - loss: 0.3320 - accuracy: 0.8643
# Epoch 3/50
# 8000/8000 [==============================] - 0s 4us/step - loss: 0.3320 - accuracy: 0.8646
# Epoch 4/50
# 8000/8000 [==============================] - 0s 4us/step - loss: 0.3320 - accuracy: 0.8643
# Epoch 5/50
# 8000/8000 [==============================] - 0s 4us/step - loss: 0.3320 - accuracy: 0.8644
# Epoch 6/50
# 8000/8000 [==============================] - 0s 4us/step - loss: 0.3320 - accuracy: 0.8640
# Epoch 7/50
# 1000/8000 [==>...........................] - ETA: 0s - loss: 0.3285 - accuracy: 0.8570
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   """Entry point for launching an IPython kernel.
# ...

# %%
Y_pred = classifier.predict(X_test)

# %%
Y_pred = Y_pred > 0.5

# %%
Y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
Y_test
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test,Y_pred)
# Out:
# array([[1512,   83],
#        [ 195,  210]])

# %%
1722/2000
# Out:
# 0.861

# %%
df.columns
# Out:
# Index(['CreditScore', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts',
#        'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited', 'Germany',
#        'Spain'],
#       dtype='object')

# %%
df.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619       0   42       2       0.00              1          1
# 1          608       0   41       1   83807.86              1          0
# 2          502       0   42       8  159660.80              3          1
# 3          699       0   39       1       0.00              2          0
# 4          850       0   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Germany  Spain
# 0               1        101348.88       1        0      0
# 1               1        112542.58       0        0      1
# 2               0        113931.57       1        0      0
# 3               0         93826.63       0        0      0
# 4               1         79084.10       0        0      1

# %%
classifier.predict(stscaler.transform(np.array([[600,1,40,3,60000,2,1,1,50000,0,0]])))
# Out:
# array([[0.0289514]], dtype=float32)

# %%
Y_pred = classifier.predict(X)

# %%
Y_pred
# Out:
# array([[0.43101594],
#        [0.28156108],
#        [0.97585183],
#        ...,
#        [0.161208  ],
#        [0.14046247],
#        [0.16233252]], dtype=float32)

# %%
pd.DataFrame(X)
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.326221 -1.095988  0.293517 -1.041760 -1.225848 -0.911583  0.646092
# 1    -0.440036 -1.095988  0.198164 -1.387538  0.117350 -0.911583 -1.547768
# 2    -1.536794 -1.095988  0.293517  1.032908  1.333053  2.527057  0.646092
# 3     0.501521 -1.095988  0.007457 -1.387538 -1.225848  0.807737 -1.547768
# 4     2.063884 -1.095988  0.388871 -1.041760  0.785728 -0.911583  0.646092
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  1.246488  0.912419  0.007457 -0.004426 -1.225848  0.807737  0.646092
# 9996 -1.391939  0.912419 -0.373958  1.724464 -0.306379 -0.911583  0.646092
# 9997  0.604988 -1.095988 -0.278604  0.687130 -1.225848 -0.911583 -1.547768
# 9998  1.256835  0.912419  0.293517 -0.695982 -0.022608  0.807737  0.646092
# 9999  1.463771 -1.095988 -1.041433 -0.350204  0.859965 -0.911583  0.646092
#
#              7         8         9        10
# ...

# %%
ds["Rating"] = Y_pred

# %%
ds.sort_values("Rating",ascending=True).head(10)
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography Gender  Age  \
# 4716       4717    15805764     Hallahan          646    France   Male   18
# 1953       1954    15675190         Chia          623    France   Male   21
# 5872       5873    15684248         Meng          658     Spain   Male   21
# 6309       6310    15785342        Shipp          705    France   Male   25
# 5707       5708    15649451        Yates          746    France   Male   25
# 6966       6967    15689661     Gorbunov          663    France   Male   22
# 9563       9564    15624374      Maclean          703    France   Male   28
# 7666       7667    15813192  Chukwuemeka          494    France   Male   25
# 9729       9730    15615330   Tretiakova          651    France   Male   23
# 6103       6104    15571144         Ives          655    France   Male   28
#
#       Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 4716      10      0.0              2          0               1
# ...
